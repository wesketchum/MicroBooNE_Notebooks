# %%
import ROOT
ROOT.gStyle.SetOptStat(0)
ROOT.enableJSVis()
# Out:
# Welcome to JupyROOT 6.12/06

# %%
#f = ROOT.TFile("/uboone/data/users/wketchum/nue_tune3_vtx_ntuple_pandoraNu_300files.root","READ")
#f = ROOT.TFile("/uboone/data/users/wketchum/nue_tune3_vtx_ntuple_tmp.root","READ")
#f = ROOT.TFile("/uboone/data/users/wketchum/nue_tune3_vtx_ntuple_pnu_tmp.root","READ")
f = ROOT.TFile("/uboone/data/users/wketchum/nue_tune3_vtx_ntuple_pnu_tmp.root","READ")
nt = f.Get("nt")

# %%
c = ROOT.TCanvas("c")
#nt.Draw("q2>>(25,0.,0.5)","vtx_dist<10 && lep_p>0")
nt.Draw("vtx_dist:vtx_x","vtx_dist<10","colz")
c.Draw()
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# <div id="root_plot_12"
#      style="width: 696px; height: 472px">
# </div>
#
# <script>
#  requirejs.config({
#      paths: {
#        'JSRootCore' : 'https://root.cern.ch/js/notebook//scripts/JSRootCore',
#      }
#    });
#  require(['JSRootCore'],
#      function(Core) {
# ...

# %%
cvtx = ROOT.TCanvas("cvtx","",1000,1200);
cvtx.Divide(1,3);
cvtx.cd(1);
nt.Draw("vtx_dist:nu_x","vtx_dist<20","colz")
cvtx.cd(2);
nt.Draw("vtx_dist:nu_y","vtx_dist<20","colz")
cvtx.cd(3);
nt.Draw("vtx_dist:nu_z","vtx_dist<20","colz")
cvtx.Draw()
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: cvtx
# <div id="root_plot_13"
#      style="width: 996px; height: 1172px">
# </div>
#
# <script>
#  requirejs.config({
#      paths: {
#        'JSRootCore' : 'https://root.cern.ch/js/notebook//scripts/JSRootCore',
#      }
#    });
#  require(['JSRootCore'],
#      function(Core) {
# ...

# %%
nt.Draw("vtx_dist:vtx_z","vtx_dist<10","colz")
c.Draw()
# Out:
# <div id="root_plot_14"
#      style="width: 696px; height: 472px">
# </div>
#
# <script>
#  requirejs.config({
#      paths: {
#        'JSRootCore' : 'https://root.cern.ch/js/notebook//scripts/JSRootCore',
#      }
#    });
#  require(['JSRootCore'],
#      function(Core) {
# ...

# %%
cut_all = ROOT.TString("lep_p>0.0");
cut_reco = cut_all + ROOT.TString(" && vtx_dist<10");

# %%
h_nue_all = ROOT.TH1F("h_nue_all",";E_{#nu};",29,0.1,3)
h_nue_10 = ROOT.TH1F("h_nue_10",";E_{#nu};",29,0.1,3)
h_nue_eff = ROOT.TH1F("h_nue_eff",";E_{#nu};efficiency",29,0.1,3)

h_q2_all = ROOT.TH1F("h_q2_all",";Q^{2};",25,0.,2.5)
h_q2_10 = ROOT.TH1F("h_q2_10",";Q^{2};",25,0.,2.5)
h_q2_eff = ROOT.TH1F("h_q2_eff",";Q^{2};efficiency",25,0.,2.5)

h_lepp_all = ROOT.TH1F("h_lepp_all",";p_{l};",25,0.1,2.6)
h_lepp_10 = ROOT.TH1F("h_lepp_10",";p_{l};",25,0.1,2.6)
h_lepp_eff = ROOT.TH1F("h_lepp_eff",";p_{l};efficiency",25,0.1,2.6)

h_pke_all = ROOT.TH1F("h_pke_all",";KE_{p};",25,0.,0.5)
h_pke_10 = ROOT.TH1F("h_pke_10",";KE_{p};",25,0.,0.5)
h_pke_eff = ROOT.TH1F("h_pke_eff",";KE_{p};efficiency",25,0.,0.5)

nt.SetLineColor(ROOT.kBlack);

nt.Project("h_nue_all","nu_e",cut_all.Data());
nt.Project("h_nue_10","nu_e",cut_reco.Data());
nt.Project("h_nue_eff","nu_e",cut_reco.Data());
h_nue_eff.Divide(h_nue_all);

nt.Project("h_q2_all","q2",cut_all.Data());
nt.Project("h_q2_10","q2",cut_reco.Data());
nt.Project("h_q2_eff","q2",cut_reco.Data());
h_q2_eff.Divide(h_q2_all);

nt.Project("h_lepp_all","lep_p",cut_all.Data());
nt.Project("h_lepp_10","lep_p",cut_reco.Data());
nt.Project("h_lepp_eff","lep_p",cut_reco.Data());
h_lepp_eff.Divide(h_lepp_all);

nt.Project("h_pke_all","p_ke",cut_all.Data());
nt.Project("h_pke_10","p_ke",cut_reco.Data());
nt.Project("h_pke_eff","p_ke",cut_reco.Data());
h_pke_eff.Divide(h_pke_all);

h_nue_eff.SetMinimum(0.0); h_nue_eff.SetMaximum(1.0);
h_q2_eff.SetMinimum(0.0); h_q2_eff.SetMaximum(1.0);
h_lepp_eff.SetMinimum(0.0); h_lepp_eff.SetMaximum(1.0);
h_pke_eff.SetMinimum(0.0); h_pke_eff.SetMaximum(1.0);
# Out:
# Warning in <TFile::Append>: Replacing existing TH1: h_nue_all (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: h_nue_10 (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: h_nue_eff (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: h_q2_all (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: h_q2_10 (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: h_q2_eff (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: h_lepp_all (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: h_lepp_10 (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: h_lepp_eff (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: h_pke_all (Potential memory leak).
# Warning in <TFile::Append>: Replacing existing TH1: h_pke_10 (Potential memory leak).
# ...

# %%
cut_all_wscale = ROOT.TString("(") + cut_all+ROOT.TString(")*3./Entries$");

# %%
c_eff = ROOT.TCanvas("c_eff","TrajCluster Efficiencies",1000,1000)
nt.SetLineColor(ROOT.kRed);
c_eff.Divide(2,2)
c_eff.cd(1)
h_nue_eff.Draw()
h_nue_eff.GetYaxis().SetTitleOffset(1.0);
nt.Draw("nu_e",cut_all_wscale.Data(),"HISTSAME")
c_eff.cd(2)
h_q2_eff.Draw()
h_q2_eff.GetYaxis().SetTitleOffset(1.0);
nt.Draw("q2",cut_all_wscale.Data(),"HISTSAME")
c_eff.cd(3)
h_lepp_eff.Draw()
h_lepp_eff.GetYaxis().SetTitleOffset(1.0);
nt.Draw("lep_p",cut_all_wscale.Data(),"HISTSAME")
c_eff.cd(4)
h_pke_eff.Draw()
h_pke_eff.GetYaxis().SetTitleOffset(1.0);
nt.Draw("p_ke",cut_all_wscale.Data(),"HISTSAME")
c_eff.cd()

txt = ROOT.TLatex(0.3,0.96,"PandoraNu Efficiencies, BNB Intrinsice #nu_{e}");
#txt = ROOT.TLatex(0.3,0.96,"PandoraNu Efficiencies, BNB Intrinsice #nu_{e}, n_{p}>0");
txt.SetTextSize(20);
txt.Draw();

leg = ROOT.TLegend(0.3,0.7,0.5,0.8);
leg.AddEntry(h_nue_eff,"Reco Efficiency","l");
leg.AddEntry(nt,"Normalized Distribution","l");
leg.Draw();
c_eff.Draw()
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c_eff
# <div id="root_plot_16"
#      style="width: 996px; height: 972px">
# </div>
#
# <script>
#  requirejs.config({
#      paths: {
#        'JSRootCore' : 'https://root.cern.ch/js/notebook//scripts/JSRootCore',
#      }
#    });
#  require(['JSRootCore'],
#      function(Core) {
# ...

# %%
h_np_all = ROOT.TH1F("h_np_all",";N_{p};",6,0,6)
h_np_10 = ROOT.TH1F("h_np_10",";N_{p};",6,0,6)
h_np_eff = ROOT.TH1F("h_np_eff",";N_{p};efficiency",6,0,6)

nt.Project("h_np_all","n_p","vtx_dist<999 && lep_p>0.03 && nu_e<0.6");
nt.Project("h_np_10","n_p","vtx_dist<10 && lep_p>0.03 && nu_e<0.6");
nt.Project("h_np_eff","n_p","vtx_dist<10 && lep_p>0.03 && nu_e<0.6");
h_np_eff.Divide(h_np_all);

c.cd();
h_np_eff.Draw();
c.Draw();
# Out:
# <div id="root_plot_5"
#      style="width: 696px; height: 472px">
# </div>
#
# <script>
#  requirejs.config({
#      paths: {
#        'JSRootCore' : 'https://root.cern.ch/js/notebook//scripts/JSRootCore',
#      }
#    });
#  require(['JSRootCore'],
#      function(Core) {
# ...
